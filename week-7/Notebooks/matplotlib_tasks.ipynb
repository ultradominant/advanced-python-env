# %%
import matplotlib.pyplot as plt

# %%
names = ["Alice", "Bob", "Charlie", "David", "Eva"]
scores = [85, 78, 92, 88, 90]

# %%
plt.plot(names, scores)
plt.xlabel("Students")
plt.ylabel("Scores")
plt.title("Students Scores Line Plot")
plt.show()

# %%
plt.bar(names, scores)
plt.xlabel("Students")
plt.ylabelll
